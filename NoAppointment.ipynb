# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('KaggleV2-May-2016.csv')

# %%
df.shape
# Out:
# (110527, 14)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['PatientId'].nunique()
# Out:
# 62299

# %%
df['PatientId'].duplicated().sum()
# Out:
# 48228

# %%
df.duplicated(['PatientId', 'No-show']).sum()
# Out:
# 38710

# %%
df.info
# Out:
# <bound method DataFrame.info of            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
mask=df.query('Age==-1')
mask
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 99832  4.659432e+14        5775010      F  2016-06-06T08:58:13Z
#
#              AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 99832  2016-06-06T00:00:00Z   -1         ROMÃO            0             0
#
#        Diabetes  Alcoholism  Handcap  SMS_received No-show
# 99832         0           0        0             0      No

# %%
df.drop(index=99832,inplace=True)

# %%
df.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105260e+05   1.105260e+05  110526.000000  110526.000000
# mean   1.474934e+14   5.675304e+06      37.089219       0.098266
# std    2.560943e+14   7.129544e+04      23.110026       0.297676
# min    3.921784e+04   5.030230e+06       0.000000       0.000000
# 25%    4.172536e+12   5.640285e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680572e+06      37.000000       0.000000
# 75%    9.438963e+13   5.725523e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110526.000000  110526.000000  110526.000000  110526.000000
# mean        0.197248       0.071865       0.030400       0.022248
# std         0.397923       0.258266       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.rename(columns={'Hipertension':'Hypertension'},inplace=True)

# %%
df.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105260e+05   1.105260e+05  110526.000000  110526.000000
# mean   1.474934e+14   5.675304e+06      37.089219       0.098266
# std    2.560943e+14   7.129544e+04      23.110026       0.297676
# min    3.921784e+04   5.030230e+06       0.000000       0.000000
# 25%    4.172536e+12   5.640285e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680572e+06      37.000000       0.000000
# 75%    9.438963e+13   5.725523e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hypertension       Diabetes     Alcoholism        Handcap  \
# count  110526.000000  110526.000000  110526.000000  110526.000000
# mean        0.197248       0.071865       0.030400       0.022248
# std         0.397923       0.258266       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.drop_duplicates(['PatientId','No-show'],inplace=True)

# %%
df.drop(['AppointmentID','PatientId','ScheduledDay','AppointmentDay'],inplace=True,axis=1)

# %%
df.head()
# Out:
#   Gender  Age      Neighbourhood  Scholarship  Hypertension  Diabetes  \
# 0      F   62    JARDIM DA PENHA            0             1         0
# 1      M   56    JARDIM DA PENHA            0             0         0
# 2      F   62      MATA DA PRAIA            0             0         0
# 3      F    8  PONTAL DE CAMBURI            0             0         0
# 4      F   56    JARDIM DA PENHA            0             1         1
#
#    Alcoholism  Handcap  SMS_received No-show
# 0           0        0             0      No
# 1           0        0             0      No
# 2           0        0             0      No
# 3           0        0             0      No
# 4           0        0             0      No

# %%
df.hist(figsize=(16,6.5))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Scholarship'}>,
#         <Axes: title={'center': 'Hypertension'}>],
#        [<Axes: title={'center': 'Diabetes'}>,
#         <Axes: title={'center': 'Alcoholism'}>,
#         <Axes: title={'center': 'Handcap'}>],
#        [<Axes: title={'center': 'SMS_received'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
dfshow=df["No-show"]=='No'
dfNoShow=df["No-show"]=='Yes'

# %%
df[dfshow].count(),df[dfNoShow].count()
# Out:
# (Gender           54153
#  Age              54153
#  Neighbourhood    54153
#  Scholarship      54153
#  Hypertension     54153
#  Diabetes         54153
#  Alcoholism       54153
#  Handcap          54153
#  SMS_received     54153
#  No-show          54153
#  dtype: int64,
#  Gender           17663
#  Age              17663
#  Neighbourhood    17663
#  Scholarship      17663
#  Hypertension     17663
#  Diabetes         17663
#  Alcoholism       17663
#  Handcap          17663
#  SMS_received     17663
#  No-show          17663
#  dtype: int64)

# %%
df[dfshow].mean(),df[dfNoShow].mean()
# Out:
# <ipython-input-44-d557d5010628>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[dfshow].mean(),df[dfNoShow].mean()
# <ipython-input-44-d557d5010628>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[dfshow].mean(),df[dfNoShow].mean()
# (Age             37.229166
#  Scholarship      0.091334
#  Hypertension     0.202944
#  Diabetes         0.072868
#  Alcoholism       0.023600
#  Handcap          0.020904
#  SMS_received     0.297232
#  dtype: float64,
#  Age             34.376267
#  Scholarship      0.108419
# ...

# %%
def attendance(df,col_name,attended,absent):
  plt.figure(figsize=(16,4))
  df[col_name][dfshow].hist(bins=10,alpha=.5,label='show',color='red')
  df[col_name][dfNoShow].hist(bins=10,alpha=.5,label='Noshow',color='blue')
  plt.legend()
  plt.xlabel('Age')
  plt.ylabel('patients number')
attendance(df,'Age',dfshow,dfNoShow)

# %%
plt.figure(figsize=(16,4))
df[dfshow].groupby(['Hypertension','Diabetes']).mean(['Age']).plot(kind='bar',color='blue',label='show')
df[dfNoShow].groupby(['Hypertension','Diabetes']).mean(['Age']).plot(kind='bar',color='red',label='NoShow')
plt.legend()
plt.title('comparison')
plt.xlabel('choronic disease')
plt.ylabel('age')
# Out:
# Text(0, 0.5, 'age')

# %%
def attendance(df,col_name,attended,absent):
  plt.figure(figsize=(16,4))
  df[col_name][dfNoShow].value_counts(normalize=True).plot(kind='pie',label='noShow')
  plt.legend()
  plt.xlabel('Gender')
  plt.ylabel('patients number')
attendance(df,'Gender',dfshow,dfNoShow)

# %%
def attendance(df,col_name,attended,absent):
  plt.figure(figsize=(16,4))
  df[col_name][dfshow].value_counts(normalize=True).plot(kind='pie',label='noShow')
  plt.legend()
  plt.xlabel('Gender')
  plt.ylabel('patients number')
attendance(df,'Gender',dfshow,dfNoShow)

# %%
plt.figure(figsize=(16,4))
df[dfshow].groupby('Gender').mean()['Age'].plot(kind='bar',color='red',label='show')
df[dfNoShow].groupby('Gender').mean()['Age'].plot(kind='bar',color='blue',label='noShow')
plt.legend()
plt.xlabel('Gender')
plt.ylabel('patients number')
# Out:
# <ipython-input-50-95b50ac57cc7>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[dfshow].groupby('Gender').mean()['Age'].plot(kind='bar',color='red',label='show')
# <ipython-input-50-95b50ac57cc7>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[dfNoShow].groupby('Gender').mean()['Age'].plot(kind='bar',color='blue',label='noShow')
# Text(0, 0.5, 'patients number')

# %%
def attendance(df,col_name,attended,absent):
  plt.figure(figsize=(16,4))
  df[col_name][dfshow].hist(bins=15,alpha=.5,label='show',color='red')
  df[col_name][dfNoShow].hist(bins=15,alpha=.5,label='Noshow',color='blue')
  plt.legend()
  plt.xlabel('Age')
  plt.ylabel('patients number')
attendance(df,'SMS_received',dfshow,dfNoShow)

# %%
plt.figure(figsize=(14,8))
df[dfshow]['Neighbourhood'].value_counts().plot(kind='bar',label='show',color='red')
df[dfNoShow]['Neighbourhood'].value_counts().plot(kind='bar',label='noshow',color='blue')
plt.legend()
plt.title('comparison')
plt.xlabel('neighbirhood')
plt.ylabel('number')
# Out:
# Text(0, 0.5, 'number')

# %%
plt.figure(figsize=(14,8))
df[dfshow].groupby('Neighbourhood').SMS_received.mean().plot(kind='bar',label='show',color='red')
df[dfNoShow].groupby('Neighbourhood').SMS_received.mean().plot(kind='bar',label='noshow',color='blue')
plt.legend()
plt.title('comparison')
plt.xlabel('neighbirhood')
plt.ylabel('number')
# Out:
# Text(0, 0.5, 'number')
